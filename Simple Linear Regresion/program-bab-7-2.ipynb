# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

penjualan = np.array([6, 5, 5, 4, 4, 3, 2, 2, 2, 1])
harga = np.array([16000, 18000, 27000, 34000, 50000, 68000, 65000, 81000, 85000, 90000])

# %matplotlib inline
plt.scatter(penjualan, harga)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

penjualan = np.array([6, 5, 5, 4, 4, 3, 2, 2, 2, 1])
harga = np.array([16000, 18000, 27000, 34000, 50000, 68000, 65000, 81000, 85000, 90000])

# %matplotlib inline
plt.scatter(penjualan, harga)
# plt.show()

penjualan = penjualan.reshape(-1, 1)
linreg = LinearRegression()
linreg.fit(penjualan, harga)

plt.scatter(penjualan, harga, color = 'red')
plt.plot(penjualan, linreg.predict(penjualan))

print("Coefficients: ", linreg.coef_)
print("Intercept: ", linreg.intercept_)

Coefficients = [-16500.]
Intercept = 109500.0
plt.show()
# Out:
# Coefficients:  [-16500.]
# Intercept:  109500.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

data = pd.read_csv('salary_dataset.csv')

# Memisahkan fitur (X) dan target (y)
year = data[['YearsExperience']]
salary = data['Salary']

plt.scatter(year, salary)

# Reshape salary if needed
salary = salary.values.reshape(-1, 1)

linreg = LinearRegression()
linreg.fit(year, salary)

plt.scatter(year, salary, color='red')
plt.plot(year, linreg.predict(year), color='blue')

print("Coefficients: ", )
print("Intercept: ", linreg.intercept_)

plt.show()
# Out:
# Coefficients:
# Intercept:  [24848.20396652]
